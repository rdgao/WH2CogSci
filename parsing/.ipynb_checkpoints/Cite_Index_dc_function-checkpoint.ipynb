# %%
import pandas as pd
import string as st
import matplotlib
import numpy as np
import os
from sklearn import decomposition, metrics, cluster

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# - fix naming convention to be consistent in all 3 years
# - combine notebooks
# - make function to produce JMatrix

# %%
def make_JMatrix(cited_folder):
    Jlist = os.listdir(cited_folder)

# %%
#Create list of Journal file names
#Jlist = os.listdir('../data/Cogs_2014/Cited_2014')
Jlist = os.listdir('../data/cite_data_2007')
#Jlist = os.listdir('../data/Cogs_2000/Cited_2000')
if '.DS_Store' in Jlist:
    Jlist.remove('.DS_Store')
#Jlist=[x.lower() for x in Jlist]
Jlist.sort()

# %%
#RUN for 2000 & 2014 data ONLY

jj=''.join(Jlist)
Jabbr=jj.split(".csv")
Jabbr=Jabbr[:-1] #for some reason the loop cant run bc there is some '' blank entry in the list

# %%
#Creates Dictionary for mapping file name to file abbreviation
JDict_map=dict(zip(Jabbr, Jlist))
df_names=Jlist
JMatrix=pd.DataFrame(data=np.zeros((len(Jlist),len(Jlist))), index=df_names, columns= df_names)

# %%
JDict_map
# Out:
# {'AM J PSYCHOL': 'AM J PSYCHOL.csv',
#  'BEHAV BRAIN SCI': 'BEHAV BRAIN SCI.csv',
#  'BEHAV RES METHODS': 'BEHAV RES METHODS.csv',
#  'BRAIN LANG': 'BRAIN LANG.csv',
#  'BRIT J PSYCHOL': 'BRIT J PSYCHOL.csv',
#  'COGN LINGUIST': 'COGN LINGUIST.csv',
#  'COGN SYST RES': 'COGN SYST RES.csv',
#  'COGNITION': 'COGNITION.csv',
#  'COGNITIVE PSYCHOL': 'COGNITIVE PSYCHOL.csv',
#  'COGNITIVE SCI': 'COGNITIVE SCI.csv',
#  'COMPUT EDUC': 'COMPUT EDUC.csv',
#  'COMPUT HUM BEHAV': 'COMPUT HUM BEHAV.csv',
#  'CONTEMP EDUC PSYCHOL': 'CONTEMP EDUC PSYCHOL.csv',
#  'DEV PSYCHOL': 'DEV PSYCHOL.csv',
#  'DEVELOPMENTAL SCI': 'DEVELOPMENTAL SCI.csv',
#  'EDUC PSYCHOL REV': 'EDUC PSYCHOL REV.csv',
#  'ETR&D-EDUC TECH RES': 'ETR&D-EDUC TECH RES.csv',
#  'INT J HUM-COMPUT ST': 'INT J HUM-COMPUT ST.csv',
#  'INT J SCI EDUC': 'INT J SCI EDUC.csv',
#  'J CHILD LANG': 'J CHILD LANG.csv',
#  'J COGNITIVE NEUROSCI': 'J COGNITIVE NEUROSCI.csv',
#  'J EDUC PSYCHOL': 'J EDUC PSYCHOL.csv',
#  'J ENG EDUC': 'J ENG EDUC.csv',
#  'J EXP PSYCHOL GEN': 'J EXP PSYCHOL GEN.csv',
#  'J EXP PSYCHOL HUMAN': 'J EXP PSYCHOL HUMAN.csv',
#  'J EXP PSYCHOL LEARN': 'J EXP PSYCHOL LEARN.csv',
#  'J LEARN SCI': 'J LEARN SCI.csv',
#  'J MEM LANG': 'J MEM LANG.csv',
#  'J PERS SOC PSYCHOL': 'J PERS SOC PSYCHOL.csv',
#  'LANG COGNITIVE PROC': 'LANG COGNITIVE PROC.csv',
#  'LEARN INSTR': 'LEARN INSTR.csv',
#  'MEM COGNITION': 'MEM COGNITION.csv',
#  'PSYCHOL BULL': 'PSYCHOL BULL.csv',
#  'PSYCHOL LEARN MOTIV': 'PSYCHOL LEARN MOTIV.csv',
#  'PSYCHOL REV': 'PSYCHOL REV.csv',
#  'PSYCHOL SCI': 'PSYCHOL SCI.csv',
#  'PSYCHON B REV': 'PSYCHON B REV.csv',
#  'Q J EXP PSYCHOL': 'Q J EXP PSYCHOL.csv',
#  'THINK REASONING': 'THINK REASONING.csv',
#  'TRENDS COGN SCI': 'TRENDS COGN SCI.csv'}

# %%
# For loop plan
#data_folder = '../data/Cogs_2014/Cited_2014/'
#data_folder = '../data/Cogs_2000/Cited_2000/'
data_folder = '../data/cite_data_2007/'
for i, Ji in enumerate(Jlist):
    print(i, Ji)
    file = open(data_folder+Jlist[i],'r')
    #file = open(Jlist[i],'r')
    data = pd.read_csv(file)[:-2]    
    #for j, Jj in enumerate(Jabbr): original
    for j, Jj in enumerate(Jlist):
        #j_abbr = Jj.split('.csv')[0]
        num_j_cited_i_row = data[data['Unnamed: 2']==Jabbr[j]]['Unnamed: 3']
        try:
            num_j_cited_i = int(num_j_cited_i_row)
        except:
            num_j_cited_i = 0        

        JMatrix[Jlist[i]][JDict_map[Jabbr[j]]] = num_j_cited_i
# Out:
# 0 AM J PSYCHOL.csv
# 1 BEHAV BRAIN SCI.csv
# 2 BEHAV RES METHODS.csv
# 3 BRAIN LANG.csv
# 4 BRIT J PSYCHOL.csv
# 5 COGN LINGUIST.csv
# 6 COGN SYST RES.csv
# 7 COGNITION.csv
# 8 COGNITIVE PSYCHOL.csv
# 9 COGNITIVE SCI.csv
# 10 COMPUT EDUC.csv
# 11 COMPUT HUM BEHAV.csv
# 12 CONTEMP EDUC PSYCHOL.csv
# 13 DEV PSYCHOL.csv
# 14 DEVELOPMENTAL SCI.csv
# 15 EDUC PSYCHOL REV.csv
# 16 ETR&D-EDUC TECH RES.csv
# 17 INT J HUM-COMPUT ST.csv
# 18 INT J SCI EDUC.csv
# 19 J CHILD LANG.csv
# 20 J COGNITIVE NEUROSCI.csv
# 21 J EDUC PSYCHOL.csv
# 22 J ENG EDUC.csv
# 23 J EXP PSYCHOL GEN.csv
# 24 J EXP PSYCHOL HUMAN.csv
# 25 J EXP PSYCHOL LEARN.csv
# 26 J LEARN SCI.csv
# 27 J MEM LANG.csv
# 28 J PERS SOC PSYCHOL.csv
# 29 LANG COGNITIVE PROC.csv
# 30 LEARN INSTR.csv
# 31 MEM COGNITION.csv
# 32 PSYCHOL BULL.csv
# 33 PSYCHOL LEARN MOTIV.csv
# 34 PSYCHOL REV.csv
# 35 PSYCHOL SCI.csv
# 36 PSYCHON B REV.csv
# 37 Q J EXP PSYCHOL.csv
# 38 THINK REASONING.csv
# 39 TRENDS COGN SCI.csv

# %%
# each column is the incoming citations INTO that journal (at col j)
# Looking at the parent journal cognitive sci the which is at the top of this graph,
# the journals on the left are citing the journals at the top x number of times from 2007 and all prev years
# THE DATABASE, JCReport, calls these "Citation Values"
JMatrix
# Out:
#                           AM J PSYCHOL.csv  BEHAV BRAIN SCI.csv  \
# AM J PSYCHOL.csv                      24.0                  7.0
# BEHAV BRAIN SCI.csv                    0.0                 39.0
# BEHAV RES METHODS.csv                  8.0                  6.0
# BRAIN LANG.csv                         4.0                 30.0
# BRIT J PSYCHOL.csv                     3.0                 10.0
# COGN LINGUIST.csv                      0.0                  0.0
# COGN SYST RES.csv                      0.0                  8.0
# COGNITION.csv                         10.0                 47.0
# COGNITIVE PSYCHOL.csv                  3.0                 17.0
# COGNITIVE SCI.csv                     11.0                 37.0
# COMPUT EDUC.csv                        0.0                  0.0
# COMPUT HUM BEHAV.csv                   0.0                  2.0
# CONTEMP EDUC PSYCHOL.csv               0.0                  4.0
# DEV PSYCHOL.csv                        4.0                 20.0
# DEVELOPMENTAL SCI.csv                  4.0                 36.0
# EDUC PSYCHOL REV.csv                   5.0                  2.0
# ETR&D-EDUC TECH RES.csv                0.0                  0.0
# INT J HUM-COMPUT ST.csv                0.0                  0.0
# INT J SCI EDUC.csv                     0.0                  0.0
# J CHILD LANG.csv                       0.0                  4.0
# J COGNITIVE NEUROSCI.csv              12.0                 40.0
# J EDUC PSYCHOL.csv                     3.0                  4.0
# J ENG EDUC.csv                         0.0                  0.0
# J EXP PSYCHOL GEN.csv                  8.0                 21.0
# J EXP PSYCHOL HUMAN.csv               15.0                 41.0
# J EXP PSYCHOL LEARN.csv               26.0                 33.0
# J LEARN SCI.csv                        0.0                  0.0
# J MEM LANG.csv                        12.0                 38.0
# J PERS SOC PSYCHOL.csv                 3.0                 32.0
# LANG COGNITIVE PROC.csv                8.0                 21.0
# LEARN INSTR.csv                        2.0                  2.0
# MEM COGNITION.csv                     64.0                 43.0
# PSYCHOL BULL.csv                       9.0                 25.0
# PSYCHOL LEARN MOTIV.csv                0.0                  0.0
# PSYCHOL REV.csv                       19.0                 18.0
# PSYCHOL SCI.csv                        3.0                 40.0
# PSYCHON B REV.csv                     20.0                 41.0
# Q J EXP PSYCHOL.csv                   21.0                 19.0
# THINK REASONING.csv                    4.0                  9.0
# TRENDS COGN SCI.csv                    6.0                 20.0
#
#                           BEHAV RES METHODS.csv  BRAIN LANG.csv  \
# AM J PSYCHOL.csv                            0.0             0.0
# BEHAV BRAIN SCI.csv                         0.0             0.0
# BEHAV RES METHODS.csv                     234.0            18.0
# BRAIN LANG.csv                             13.0           574.0
# BRIT J PSYCHOL.csv                          5.0             4.0
# COGN LINGUIST.csv                           0.0             0.0
# COGN SYST RES.csv                           0.0             0.0
# COGNITION.csv                              21.0            34.0
# COGNITIVE PSYCHOL.csv                      10.0             4.0
# COGNITIVE SCI.csv                           9.0             9.0
# COMPUT EDUC.csv                             0.0             0.0
# COMPUT HUM BEHAV.csv                       27.0             0.0
# CONTEMP EDUC PSYCHOL.csv                    0.0             0.0
# DEV PSYCHOL.csv                             3.0             0.0
# DEVELOPMENTAL SCI.csv                       3.0            19.0
# EDUC PSYCHOL REV.csv                        0.0             4.0
# ETR&D-EDUC TECH RES.csv                     0.0             0.0
# INT J HUM-COMPUT ST.csv                     6.0             0.0
# INT J SCI EDUC.csv                          0.0             0.0
# J CHILD LANG.csv                            0.0             4.0
# J COGNITIVE NEUROSCI.csv                   18.0           103.0
# J EDUC PSYCHOL.csv                          0.0             0.0
# J ENG EDUC.csv                              0.0             0.0
# J EXP PSYCHOL GEN.csv                      12.0             6.0
# J EXP PSYCHOL HUMAN.csv                    19.0             4.0
# J EXP PSYCHOL LEARN.csv                    37.0             8.0
# J LEARN SCI.csv                             0.0             0.0
# J MEM LANG.csv                             11.0            81.0
# J PERS SOC PSYCHOL.csv                      9.0             0.0
# LANG COGNITIVE PROC.csv                    10.0            53.0
# LEARN INSTR.csv                             3.0             0.0
# MEM COGNITION.csv                          46.0            21.0
# PSYCHOL BULL.csv                            8.0            16.0
# PSYCHOL LEARN MOTIV.csv                     0.0             0.0
# PSYCHOL REV.csv                             9.0             7.0
# PSYCHOL SCI.csv                            11.0             4.0
# PSYCHON B REV.csv                          39.0            11.0
# Q J EXP PSYCHOL.csv                        16.0             9.0
# THINK REASONING.csv                         0.0             0.0
# TRENDS COGN SCI.csv                         0.0             5.0
#
#                           BRIT J PSYCHOL.csv  COGN LINGUIST.csv  \
# AM J PSYCHOL.csv                         8.0                0.0
# BEHAV BRAIN SCI.csv                      0.0                0.0
# BEHAV RES METHODS.csv                   16.0                0.0
# BRAIN LANG.csv                           6.0                5.0
# BRIT J PSYCHOL.csv                      42.0                0.0
# COGN LINGUIST.csv                        0.0               87.0
# COGN SYST RES.csv                        0.0                0.0
# COGNITION.csv                           11.0                6.0
# COGNITIVE PSYCHOL.csv                    6.0                0.0
# COGNITIVE SCI.csv                        4.0                0.0
# COMPUT EDUC.csv                          0.0                0.0
# COMPUT HUM BEHAV.csv                    12.0                0.0
# CONTEMP EDUC PSYCHOL.csv                 0.0                0.0
# DEV PSYCHOL.csv                          4.0                3.0
# DEVELOPMENTAL SCI.csv                    8.0                0.0
# EDUC PSYCHOL REV.csv                     6.0                0.0
# ETR&D-EDUC TECH RES.csv                  0.0                0.0
# INT J HUM-COMPUT ST.csv                  0.0                0.0
# INT J SCI EDUC.csv                       0.0                0.0
# J CHILD LANG.csv                         0.0                4.0
# J COGNITIVE NEUROSCI.csv                 8.0                2.0
# J EDUC PSYCHOL.csv                       3.0                0.0
# J ENG EDUC.csv                           2.0                0.0
# J EXP PSYCHOL GEN.csv                    8.0                0.0
# J EXP PSYCHOL HUMAN.csv                 14.0                0.0
# J EXP PSYCHOL LEARN.csv                 17.0                0.0
# J LEARN SCI.csv                          0.0                0.0
# J MEM LANG.csv                          12.0                0.0
# J PERS SOC PSYCHOL.csv                  10.0                0.0
# LANG COGNITIVE PROC.csv                  3.0                0.0
# LEARN INSTR.csv                          3.0                0.0
# MEM COGNITION.csv                       57.0                0.0
# PSYCHOL BULL.csv                        12.0                0.0
# PSYCHOL LEARN MOTIV.csv                  0.0                2.0
# PSYCHOL REV.csv                          5.0                0.0
# PSYCHOL SCI.csv                          9.0                0.0
# PSYCHON B REV.csv                       16.0                0.0
# Q J EXP PSYCHOL.csv                     26.0                0.0
# THINK REASONING.csv                     13.0                0.0
# TRENDS COGN SCI.csv                      2.0                0.0
#
#                           COGN SYST RES.csv  COGNITION.csv  \
# AM J PSYCHOL.csv                        0.0            2.0
# BEHAV BRAIN SCI.csv                     0.0            9.0
# BEHAV RES METHODS.csv                   0.0           21.0
# BRAIN LANG.csv                          0.0           73.0
# BRIT J PSYCHOL.csv                      0.0           23.0
# COGN LINGUIST.csv                       0.0            3.0
# COGN SYST RES.csv                      12.0           15.0
# COGNITION.csv                           0.0          348.0
# COGNITIVE PSYCHOL.csv                   0.0           59.0
# COGNITIVE SCI.csv                       6.0           73.0
# COMPUT EDUC.csv                         0.0            0.0
# COMPUT HUM BEHAV.csv                    0.0            2.0
# CONTEMP EDUC PSYCHOL.csv                0.0            2.0
# DEV PSYCHOL.csv                         0.0          128.0
# DEVELOPMENTAL SCI.csv                   0.0          147.0
# EDUC PSYCHOL REV.csv                    0.0            5.0
# ETR&D-EDUC TECH RES.csv                 0.0            0.0
# INT J HUM-COMPUT ST.csv                 0.0            6.0
# INT J SCI EDUC.csv                      0.0            3.0
# J CHILD LANG.csv                        0.0           40.0
# J COGNITIVE NEUROSCI.csv                0.0           77.0
# J EDUC PSYCHOL.csv                      0.0            7.0
# J ENG EDUC.csv                          0.0            0.0
# J EXP PSYCHOL GEN.csv                   5.0           37.0
# J EXP PSYCHOL HUMAN.csv                 4.0           61.0
# J EXP PSYCHOL LEARN.csv                 0.0           76.0
# J LEARN SCI.csv                         0.0            0.0
# J MEM LANG.csv                          0.0          180.0
# J PERS SOC PSYCHOL.csv                  0.0            9.0
# LANG COGNITIVE PROC.csv                 0.0          103.0
# LEARN INSTR.csv                         0.0            3.0
# MEM COGNITION.csv                       3.0          151.0
# PSYCHOL BULL.csv                        0.0           44.0
# PSYCHOL LEARN MOTIV.csv                 0.0           22.0
# PSYCHOL REV.csv                         0.0           53.0
# PSYCHOL SCI.csv                         0.0           95.0
# PSYCHON B REV.csv                       0.0           65.0
# Q J EXP PSYCHOL.csv                     0.0           52.0
# THINK REASONING.csv                     0.0           37.0
# TRENDS COGN SCI.csv                     0.0           70.0
#
#                           COGNITIVE PSYCHOL.csv  COGNITIVE SCI.csv  \
# AM J PSYCHOL.csv                            9.0                0.0
# BEHAV BRAIN SCI.csv                         2.0                2.0
# BEHAV RES METHODS.csv                      16.0               10.0
# BRAIN LANG.csv                             15.0               14.0
# BRIT J PSYCHOL.csv                         13.0               10.0
# COGN LINGUIST.csv                           3.0               10.0
# COGN SYST RES.csv                          12.0               20.0
# COGNITION.csv                             128.0               48.0
# COGNITIVE PSYCHOL.csv                      66.0               12.0
# COGNITIVE SCI.csv                          38.0               73.0
# COMPUT EDUC.csv                             3.0               10.0
# COMPUT HUM BEHAV.csv                        8.0               17.0
# CONTEMP EDUC PSYCHOL.csv                    2.0               11.0
# DEV PSYCHOL.csv                            53.0               13.0
# DEVELOPMENTAL SCI.csv                      44.0               31.0
# EDUC PSYCHOL REV.csv                       11.0               27.0
# ETR&D-EDUC TECH RES.csv                     3.0               12.0
# INT J HUM-COMPUT ST.csv                     7.0               13.0
# INT J SCI EDUC.csv                          8.0               11.0
# J CHILD LANG.csv                            4.0                3.0
# J COGNITIVE NEUROSCI.csv                   32.0                7.0
# J EDUC PSYCHOL.csv                          5.0               11.0
# J ENG EDUC.csv                              0.0               10.0
# J EXP PSYCHOL GEN.csv                      44.0               18.0
# J EXP PSYCHOL HUMAN.csv                   123.0                7.0
# J EXP PSYCHOL LEARN.csv                    82.0               23.0
# J LEARN SCI.csv                             5.0               12.0
# J MEM LANG.csv                             83.0               43.0
# J PERS SOC PSYCHOL.csv                     19.0                0.0
# LANG COGNITIVE PROC.csv                    33.0               10.0
# LEARN INSTR.csv                             8.0               26.0
# MEM COGNITION.csv                         180.0               57.0
# PSYCHOL BULL.csv                           16.0               14.0
# PSYCHOL LEARN MOTIV.csv                    16.0                9.0
# PSYCHOL REV.csv                            80.0               35.0
# PSYCHOL SCI.csv                            40.0               15.0
# PSYCHON B REV.csv                          93.0               28.0
# Q J EXP PSYCHOL.csv                        53.0               11.0
# THINK REASONING.csv                        17.0               17.0
# TRENDS COGN SCI.csv                        26.0                2.0
#
#                                  ...           LEARN INSTR.csv  \
# AM J PSYCHOL.csv                 ...                       0.0
# BEHAV BRAIN SCI.csv              ...                       0.0
# BEHAV RES METHODS.csv            ...                       0.0
# BRAIN LANG.csv                   ...                       0.0
# BRIT J PSYCHOL.csv               ...                       4.0
# COGN LINGUIST.csv                ...                       0.0
# COGN SYST RES.csv                ...                       0.0
# COGNITION.csv                    ...                       0.0
# COGNITIVE PSYCHOL.csv            ...                       0.0
# COGNITIVE SCI.csv                ...                       3.0
# COMPUT EDUC.csv                  ...                      10.0
# COMPUT HUM BEHAV.csv             ...                      28.0
# CONTEMP EDUC PSYCHOL.csv         ...                      14.0
# DEV PSYCHOL.csv                  ...                       0.0
# DEVELOPMENTAL SCI.csv            ...                       0.0
# EDUC PSYCHOL REV.csv             ...                      23.0
# ETR&D-EDUC TECH RES.csv          ...                      18.0
# INT J HUM-COMPUT ST.csv          ...                       8.0
# INT J SCI EDUC.csv               ...                      25.0
# J CHILD LANG.csv                 ...                       0.0
# J COGNITIVE NEUROSCI.csv         ...                       0.0
# J EDUC PSYCHOL.csv               ...                      25.0
# J ENG EDUC.csv                   ...                       2.0
# J EXP PSYCHOL GEN.csv            ...                       0.0
# J EXP PSYCHOL HUMAN.csv          ...                       2.0
# J EXP PSYCHOL LEARN.csv          ...                       0.0
# J LEARN SCI.csv                  ...                       4.0
# J MEM LANG.csv                   ...                       0.0
# J PERS SOC PSYCHOL.csv           ...                       0.0
# LANG COGNITIVE PROC.csv          ...                       0.0
# LEARN INSTR.csv                  ...                      84.0
# MEM COGNITION.csv                ...                       2.0
# PSYCHOL BULL.csv                 ...                       0.0
# PSYCHOL LEARN MOTIV.csv          ...                       0.0
# PSYCHOL REV.csv                  ...                       0.0
# PSYCHOL SCI.csv                  ...                       0.0
# PSYCHON B REV.csv                ...                       0.0
# Q J EXP PSYCHOL.csv              ...                       0.0
# THINK REASONING.csv              ...                       0.0
# TRENDS COGN SCI.csv              ...                       0.0
#
#                           MEM COGNITION.csv  PSYCHOL BULL.csv  \
# AM J PSYCHOL.csv                       22.0              14.0
# BEHAV BRAIN SCI.csv                     2.0              15.0
# BEHAV RES METHODS.csv                  80.0              42.0
# BRAIN LANG.csv                         35.0              14.0
# BRIT J PSYCHOL.csv                     35.0              35.0
# COGN LINGUIST.csv                       3.0               3.0
# COGN SYST RES.csv                      10.0               8.0
# COGNITION.csv                          59.0              31.0
# COGNITIVE PSYCHOL.csv                  31.0              15.0
# COGNITIVE SCI.csv                      37.0              25.0
# COMPUT EDUC.csv                         0.0               7.0
# COMPUT HUM BEHAV.csv                    8.0              40.0
# CONTEMP EDUC PSYCHOL.csv                7.0              12.0
# DEV PSYCHOL.csv                         8.0             139.0
# DEVELOPMENTAL SCI.csv                   8.0              20.0
# EDUC PSYCHOL REV.csv                    6.0              14.0
# ETR&D-EDUC TECH RES.csv                 5.0               2.0
# INT J HUM-COMPUT ST.csv                 2.0              14.0
# INT J SCI EDUC.csv                      0.0               2.0
# J CHILD LANG.csv                        2.0               0.0
# J COGNITIVE NEUROSCI.csv               69.0              44.0
# J EDUC PSYCHOL.csv                     12.0              47.0
# J ENG EDUC.csv                          0.0               0.0
# J EXP PSYCHOL GEN.csv                  62.0              52.0
# J EXP PSYCHOL HUMAN.csv                67.0              45.0
# J EXP PSYCHOL LEARN.csv               215.0              43.0
# J LEARN SCI.csv                         0.0               0.0
# J MEM LANG.csv                        132.0              35.0
# J PERS SOC PSYCHOL.csv                  9.0             302.0
# LANG COGNITIVE PROC.csv                63.0              14.0
# LEARN INSTR.csv                         6.0              14.0
# MEM COGNITION.csv                     696.0             102.0
# PSYCHOL BULL.csv                       40.0             156.0
# PSYCHOL LEARN MOTIV.csv                 7.0               5.0
# PSYCHOL REV.csv                        94.0              78.0
# PSYCHOL SCI.csv                        43.0              80.0
# PSYCHON B REV.csv                     199.0              90.0
# Q J EXP PSYCHOL.csv                   156.0              60.0
# THINK REASONING.csv                    25.0              12.0
# TRENDS COGN SCI.csv                    28.0              23.0
#
#                           PSYCHOL LEARN MOTIV.csv  PSYCHOL REV.csv  \
# AM J PSYCHOL.csv                              0.0             20.0
# BEHAV BRAIN SCI.csv                           0.0             23.0
# BEHAV RES METHODS.csv                         4.0             85.0
# BRAIN LANG.csv                                2.0             54.0
# BRIT J PSYCHOL.csv                            4.0             14.0
# COGN LINGUIST.csv                             0.0              9.0
# COGN SYST RES.csv                             0.0             45.0
# COGNITION.csv                                16.0            130.0
# COGNITIVE PSYCHOL.csv                         2.0             78.0
# COGNITIVE SCI.csv                            12.0             74.0
# COMPUT EDUC.csv                               0.0              5.0
# COMPUT HUM BEHAV.csv                          2.0             16.0
# CONTEMP EDUC PSYCHOL.csv                      0.0             25.0
# DEV PSYCHOL.csv                               5.0             60.0
# DEVELOPMENTAL SCI.csv                         3.0             71.0
# EDUC PSYCHOL REV.csv                          5.0             41.0
# ETR&D-EDUC TECH RES.csv                       2.0             13.0
# INT J HUM-COMPUT ST.csv                       0.0             11.0
# INT J SCI EDUC.csv                            0.0              9.0
# J CHILD LANG.csv                              0.0              0.0
# J COGNITIVE NEUROSCI.csv                      3.0            123.0
# J EDUC PSYCHOL.csv                            0.0             29.0
# J ENG EDUC.csv                                0.0              2.0
# J EXP PSYCHOL GEN.csv                        18.0            134.0
# J EXP PSYCHOL HUMAN.csv                       4.0            155.0
# J EXP PSYCHOL LEARN.csv                      14.0            240.0
# J LEARN SCI.csv                               0.0              0.0
# J MEM LANG.csv                               16.0            148.0
# J PERS SOC PSYCHOL.csv                        6.0            236.0
# LANG COGNITIVE PROC.csv                       4.0             65.0
# LEARN INSTR.csv                               3.0             20.0
# MEM COGNITION.csv                            64.0            412.0
# PSYCHOL BULL.csv                              4.0            105.0
# PSYCHOL LEARN MOTIV.csv                       2.0             21.0
# PSYCHOL REV.csv                              13.0            402.0
# PSYCHOL SCI.csv                              15.0            115.0
# PSYCHON B REV.csv                            29.0            231.0
# Q J EXP PSYCHOL.csv                          38.0            165.0
# THINK REASONING.csv                           5.0             42.0
# TRENDS COGN SCI.csv                           0.0             69.0
#
#                           PSYCHOL SCI.csv  PSYCHON B REV.csv  \
# AM J PSYCHOL.csv                     13.0                9.0
# BEHAV BRAIN SCI.csv                   6.0                0.0
# BEHAV RES METHODS.csv                27.0               42.0
# BRAIN LANG.csv                       31.0               21.0
# BRIT J PSYCHOL.csv                    8.0               12.0
# COGN LINGUIST.csv                     0.0                0.0
# COGN SYST RES.csv                     6.0                5.0
# COGNITION.csv                       117.0               52.0
# COGNITIVE PSYCHOL.csv                22.0               22.0
# COGNITIVE SCI.csv                    24.0               14.0
# COMPUT EDUC.csv                       0.0                0.0
# COMPUT HUM BEHAV.csv                 11.0                4.0
# CONTEMP EDUC PSYCHOL.csv              2.0                0.0
# DEV PSYCHOL.csv                      78.0                8.0
# DEVELOPMENTAL SCI.csv                73.0               12.0
# EDUC PSYCHOL REV.csv                  3.0                2.0
# ETR&D-EDUC TECH RES.csv               0.0                0.0
# INT J HUM-COMPUT ST.csv               6.0                2.0
# INT J SCI EDUC.csv                    0.0                0.0
# J CHILD LANG.csv                      6.0                0.0
# J COGNITIVE NEUROSCI.csv             81.0               39.0
# J EDUC PSYCHOL.csv                   16.0                2.0
# J ENG EDUC.csv                        0.0                0.0
# J EXP PSYCHOL GEN.csv                46.0               47.0
# J EXP PSYCHOL HUMAN.csv             127.0              128.0
# J EXP PSYCHOL LEARN.csv              72.0              154.0
# J LEARN SCI.csv                       0.0                0.0
# J MEM LANG.csv                       59.0               65.0
# J PERS SOC PSYCHOL.csv              110.0               12.0
# LANG COGNITIVE PROC.csv              25.0               18.0
# LEARN INSTR.csv                       2.0                2.0
# MEM COGNITION.csv                   139.0              332.0
# PSYCHOL BULL.csv                     46.0               31.0
# PSYCHOL LEARN MOTIV.csv              10.0                3.0
# PSYCHOL REV.csv                      83.0              102.0
# PSYCHOL SCI.csv                     242.0               48.0
# PSYCHON B REV.csv                   169.0              247.0
# Q J EXP PSYCHOL.csv                  67.0               87.0
# THINK REASONING.csv                  11.0                7.0
# TRENDS COGN SCI.csv                  76.0               15.0
#
#                           Q J EXP PSYCHOL.csv  THINK REASONING.csv  \
# AM J PSYCHOL.csv                          0.0                  0.0
# BEHAV BRAIN SCI.csv                       0.0                  0.0
# BEHAV RES METHODS.csv                    13.0                  0.0
# BRAIN LANG.csv                            2.0                  0.0
# BRIT J PSYCHOL.csv                        7.0                  5.0
# COGN LINGUIST.csv                         0.0                  0.0
# COGN SYST RES.csv                         0.0                  0.0
# COGNITION.csv                             5.0                  0.0
# COGNITIVE PSYCHOL.csv                     2.0                  9.0
# COGNITIVE SCI.csv                         0.0                  3.0
# COMPUT EDUC.csv                           0.0                  0.0
# COMPUT HUM BEHAV.csv                      0.0                  0.0
# CONTEMP EDUC PSYCHOL.csv                  0.0                  2.0
# DEV PSYCHOL.csv                           0.0                  0.0
# DEVELOPMENTAL SCI.csv                     0.0                  0.0
# EDUC PSYCHOL REV.csv                      0.0                  0.0
# ETR&D-EDUC TECH RES.csv                   0.0                  0.0
# INT J HUM-COMPUT ST.csv                   0.0                  0.0
# INT J SCI EDUC.csv                        0.0                  0.0
# J CHILD LANG.csv                          0.0                  0.0
# J COGNITIVE NEUROSCI.csv                 11.0                  2.0
# J EDUC PSYCHOL.csv                        0.0                  0.0
# J ENG EDUC.csv                            0.0                  2.0
# J EXP PSYCHOL GEN.csv                     8.0                  0.0
# J EXP PSYCHOL HUMAN.csv                  22.0                  0.0
# J EXP PSYCHOL LEARN.csv                  11.0                  9.0
# J LEARN SCI.csv                           0.0                  0.0
# J MEM LANG.csv                            9.0                  0.0
# J PERS SOC PSYCHOL.csv                    0.0                  0.0
# LANG COGNITIVE PROC.csv                   7.0                  0.0
# LEARN INSTR.csv                           0.0                  0.0
# MEM COGNITION.csv                        42.0                 24.0
# PSYCHOL BULL.csv                          5.0                  2.0
# PSYCHOL LEARN MOTIV.csv                   0.0                  0.0
# PSYCHOL REV.csv                          15.0                  0.0
# PSYCHOL SCI.csv                           3.0                  0.0
# PSYCHON B REV.csv                        28.0                  8.0
# Q J EXP PSYCHOL.csv                      83.0                  5.0
# THINK REASONING.csv                       7.0                 57.0
# TRENDS COGN SCI.csv                       6.0                  2.0
#
#                           TRENDS COGN SCI.csv
# AM J PSYCHOL.csv                          3.0
# BEHAV BRAIN SCI.csv                      17.0
# BEHAV RES METHODS.csv                    11.0
# BRAIN LANG.csv                           56.0
# BRIT J PSYCHOL.csv                       11.0
# COGN LINGUIST.csv                         0.0
# COGN SYST RES.csv                         9.0
# COGNITION.csv                            79.0
# COGNITIVE PSYCHOL.csv                    15.0
# COGNITIVE SCI.csv                        19.0
# COMPUT EDUC.csv                           0.0
# COMPUT HUM BEHAV.csv                      0.0
# CONTEMP EDUC PSYCHOL.csv                  0.0
# DEV PSYCHOL.csv                          21.0
# DEVELOPMENTAL SCI.csv                    75.0
# EDUC PSYCHOL REV.csv                      2.0
# ETR&D-EDUC TECH RES.csv                   0.0
# INT J HUM-COMPUT ST.csv                   0.0
# INT J SCI EDUC.csv                        2.0
# J CHILD LANG.csv                          6.0
# J COGNITIVE NEUROSCI.csv                235.0
# J EDUC PSYCHOL.csv                        0.0
# J ENG EDUC.csv                            0.0
# J EXP PSYCHOL GEN.csv                    28.0
# J EXP PSYCHOL HUMAN.csv                  80.0
# J EXP PSYCHOL LEARN.csv                  34.0
# J LEARN SCI.csv                           0.0
# J MEM LANG.csv                           28.0
# J PERS SOC PSYCHOL.csv                   12.0
# LANG COGNITIVE PROC.csv                  16.0
# LEARN INSTR.csv                           2.0
# MEM COGNITION.csv                        52.0
# PSYCHOL BULL.csv                         44.0
# PSYCHOL LEARN MOTIV.csv                   5.0
# PSYCHOL REV.csv                          33.0
# PSYCHOL SCI.csv                          78.0
# PSYCHON B REV.csv                        50.0
# Q J EXP PSYCHOL.csv                      36.0
# THINK REASONING.csv                      14.0
# TRENDS COGN SCI.csv                     156.0
#
# [40 rows x 40 columns]

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.log(JMatrix))
#np.where(np.sum(JMatrix.as_matrix(), axis=0)==0)#getting nothing in the array[] means dylan didnt screw up (:
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Decomposition

# %%
# SVD and PCA gives essentially the same answer, as it should, with rotational indeterminancy
#citation_svd = decomposition.TruncatedSVD(n_components=20)
citation_svd = decomposition.PCA(n_components=20, whiten=False)

# apply matrix factorization to citation matrix
citation_svd.fit(JMatrix.as_matrix())
JMatrix_reduced = citation_svd.transform(JMatrix.as_matrix())

# how many components required to capture 95% variance?
np.where(np.cumsum(citation_svd.explained_variance_ratio_)>=0.95)[0][0]

# cog sci is element 9
ctr_j=9
print(Jabbr[ctr_j])
plt.figure(figsize=(15,4))
plt.subplot(1,4,1)
plt.plot(np.cumsum(citation_svd.explained_variance_ratio_))
plt.subplot(1,4,2)
plt.imshow(JMatrix_reduced)
plt.subplot(1,4,3)
# # Cogsci's reduced vector
# plt.plot(JMatrix_reduced[ctr_j,:],'.')
# # Cogsci's components
# plt.subplot(1,4,4)
# plt.plot(citation_svd.components_[:,ctr_j]);
# plt.tight_layout()

# %%
# k-means clustering
n_clusters = 8
clu = cluster.KMeans(n_clusters=n_clusters)

clu.fit(JMatrix_reduced)
clu_label = clu.labels_
clu_inds = np.argsort(clu_label)
clu_label
clustered_J = [[Jabbr[i] for i in np.where(clu_label==query_clu)[0]] for query_clu in range(n_clusters)]
pd.DataFrame([t for t in clustered_J], index=['Clu%i'%i for i in range(n_clusters)]).T
