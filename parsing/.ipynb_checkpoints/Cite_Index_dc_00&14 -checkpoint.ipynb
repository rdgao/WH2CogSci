# %%
import pandas as pd
import string as st
import matplotlib
import numpy as np
import os
from sklearn import decomposition, metrics, cluster

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Create list of Journal file names
#Jlist = os.listdir('../data/Cogs_2014/Cited_2014')
Jlist = os.listdir('../data/Cogs_2000/Cited_2000')
if '.DS_Store' in Jlist:
    Jlist.remove('.DS_Store')
#Jlist=[x.lower() for x in Jlist]
Jlist.sort()

# %%
#RUN for 2000 & 2014 data ONLY

jj=''.join(Jlist)
Jabbr=jj.split(".csv")
Jabbr=Jabbr[:-1] #for some reason the loop cant run bc there is some '' blank entry in the list

# %%
#Creates Dictionary for mapping file name to file abbreviation
JDict_map=dict(zip(Jabbr, Jlist))
df_names=Jlist
JMatrix=pd.DataFrame(data=np.zeros((len(Jlist),len(Jlist))), index=df_names, columns= df_names)

# %%
JDict_map
# Out:
# {'AM J PSYCHOL': 'AM J PSYCHOL.csv',
#  'AM PSYCHOL': 'AM PSYCHOL.csv',
#  'BEHAV BRAIN SCI': 'BEHAV BRAIN SCI.csv',
#  'BEHAV PROCESS': 'BEHAV PROCESS.csv',
#  'BRIT J PSYCHOL': 'BRIT J PSYCHOL.csv',
#  'CHILD DEV': 'CHILD DEV.csv',
#  'COGNITION': 'COGNITION.csv',
#  'COGNITION INSTRUCT': 'COGNITION INSTRUCT.csv',
#  'COGNITIVE PSYCHOL': 'COGNITIVE PSYCHOL.csv',
#  'COGNITIVE SCI': 'COGNITIVE SCI.csv',
#  'CONTEMP EDUC PSYCHOL': 'CONTEMP EDUC PSYCHOL.csv',
#  'DEV PSYCHOL': 'DEV PSYCHOL.csv',
#  'DEV REV': 'DEV REV.csv',
#  'HUM FACTORS': 'HUM FACTORS.csv',
#  'INT J HUM-COMPUT ST': 'INT J HUM-COMPUT ST.csv',
#  'INT J SCI EDUC': 'INT J SCI EDUC.csv',
#  'J CHILD LANG': 'J CHILD LANG.csv',
#  'J COMP PSYCHOL': 'J COMP PSYCHOL.csv',
#  'J COMPUT ASSIST LEAR': 'J COMPUT ASSIST LEAR.csv',
#  'J EDUC PSYCHOL': 'J EDUC PSYCHOL.csv',
#  'J EXP PSYCHOL ANIM B': 'J EXP PSYCHOL ANIM B.csv',
#  'J EXP PSYCHOL GEN': 'J EXP PSYCHOL GEN.csv',
#  'J EXP PSYCHOL LEARN': 'J EXP PSYCHOL LEARN.csv',
#  'J HUM EVOL': 'J HUM EVOL.csv',
#  'J LEARN SCI': 'J LEARN SCI.csv',
#  'J MEM LANG': 'J MEM LANG.csv',
#  'J PERS SOC PSYCHOL': 'J PERS SOC PSYCHOL.csv',
#  'J PRAGMATICS': 'J PRAGMATICS.csv',
#  'J PSYCHOLINGUIST RES': 'J PSYCHOLINGUIST RES.csv',
#  'J RES SCI TEACH': 'J RES SCI TEACH.csv',
#  'LEARN INSTR': 'LEARN INSTR.csv',
#  'MEM COGNITION': 'MEM COGNITION.csv',
#  'MONOGR SOC RES CHILD': 'MONOGR SOC RES CHILD.csv',
#  'ORGAN BEHAV HUM DEC': 'ORGAN BEHAV HUM DEC.csv',
#  'PHILOS PSYCHOL': 'PHILOS PSYCHOL.csv',
#  'PSYCHOL REV': 'PSYCHOL REV.csv',
#  'PSYCHOL SCI': 'PSYCHOL SCI.csv',
#  'PSYCHON B REV': 'PSYCHON B REV.csv',
#  'TRAV HUMAIN': 'TRAV HUMAIN.csv'}

# %%
# For loop plan
#data_folder = '../data/Cogs_2014/Cited_2014/'
data_folder = '../data/Cogs_2000/Cited_2000/'
for i, Ji in enumerate(Jlist):
    print(i, Ji)
    file = open(data_folder+Jlist[i],'r')
    #file = open(Jlist[i],'r')
    data = pd.read_csv(file)[:-2]    
    for j, Jj in enumerate(Jabbr):
        num_j_cited_i_row = data[data['Unnamed: 2']==Jabbr[j]]['Unnamed: 3']
        try:
            num_j_cited_i = int(num_j_cited_i_row)
        except:
            num_j_cited_i = 0        

        JMatrix[Jlist[i]][JDict_map[Jabbr[j]]] = num_j_cited_i
# Out:
# 0 AM J PSYCHOL.csv
# 1 AM PSYCHOL.csv
# 2 BEHAV BRAIN SCI.csv
# 3 BEHAV PROCESS.csv
# 4 BRIT J PSYCHOL.csv
# 5 CHILD DEV.csv
# 6 COGNITION INSTRUCT.csv
# 7 COGNITION.csv
# 8 COGNITIVE PSYCHOL.csv
# 9 COGNITIVE SCI.csv
# 10 CONTEMP EDUC PSYCHOL.csv
# 11 DEV PSYCHOL.csv
# 12 DEV REV.csv
# 13 HUM FACTORS.csv
# 14 INT J HUM-COMPUT ST.csv
# 15 INT J SCI EDUC.csv
# 16 J CHILD LANG.csv
# 17 J COMP PSYCHOL.csv
# 18 J COMPUT ASSIST LEAR.csv
# 19 J EDUC PSYCHOL.csv
# 20 J EXP PSYCHOL ANIM B.csv
# 21 J EXP PSYCHOL GEN.csv
# 22 J EXP PSYCHOL LEARN.csv
# 23 J HUM EVOL.csv
# 24 J LEARN SCI.csv
# 25 J MEM LANG.csv
# 26 J PERS SOC PSYCHOL.csv
# 27 J PRAGMATICS.csv
# 28 J PSYCHOLINGUIST RES.csv
# 29 J RES SCI TEACH.csv
# 30 LEARN INSTR.csv
# 31 MEM COGNITION.csv
# 32 MONOGR SOC RES CHILD.csv
# 33 ORGAN BEHAV HUM DEC.csv
# 34 PHILOS PSYCHOL.csv
# 35 PSYCHOL REV.csv
# 36 PSYCHOL SCI.csv
# 37 PSYCHON B REV.csv
# 38 TRAV HUMAIN.csv

# %%
# each column is the incoming citations INTO that journal (at col j)
# Looking at the parent journal cognitive sci the which is at the top of this graph,
# the journals on the left are citing the journals at the top x number of times from 2007 and all prev years
# THE DATABASE, JCReport, calls these "Citation Values"
JMatrix
# Out:
#                           AM J PSYCHOL.csv  AM PSYCHOL.csv  \
# AM J PSYCHOL.csv                      23.0            16.0
# AM PSYCHOL.csv                        40.0           411.0
# BEHAV BRAIN SCI.csv                    6.0            32.0
# BEHAV PROCESS.csv                      3.0             2.0
# BRIT J PSYCHOL.csv                     7.0             7.0
# CHILD DEV.csv                          0.0            55.0
# COGNITION INSTRUCT.csv                 0.0             6.0
# COGNITION.csv                         10.0             5.0
# COGNITIVE PSYCHOL.csv                  7.0            11.0
# COGNITIVE SCI.csv                     10.0             8.0
# CONTEMP EDUC PSYCHOL.csv               0.0            15.0
# DEV PSYCHOL.csv                        0.0            31.0
# DEV REV.csv                            0.0            27.0
# HUM FACTORS.csv                        0.0            10.0
# INT J HUM-COMPUT ST.csv                0.0             3.0
# INT J SCI EDUC.csv                     0.0             3.0
# J CHILD LANG.csv                       0.0             0.0
# J COMP PSYCHOL.csv                     3.0             4.0
# J COMPUT ASSIST LEAR.csv               0.0             2.0
# J EDUC PSYCHOL.csv                     3.0            25.0
# J EXP PSYCHOL ANIM B.csv               5.0             2.0
# J EXP PSYCHOL GEN.csv                 17.0            11.0
# J EXP PSYCHOL LEARN.csv               45.0            18.0
# J HUM EVOL.csv                         0.0             0.0
# J LEARN SCI.csv                        0.0             4.0
# J MEM LANG.csv                        12.0             6.0
# J PERS SOC PSYCHOL.csv                 5.0           126.0
# J PRAGMATICS.csv                       0.0             0.0
# J PSYCHOLINGUIST RES.csv               0.0             0.0
# J RES SCI TEACH.csv                    0.0             4.0
# LEARN INSTR.csv                        0.0             5.0
# MEM COGNITION.csv                     27.0            19.0
# MONOGR SOC RES CHILD.csv               0.0             6.0
# ORGAN BEHAV HUM DEC.csv                3.0            20.0
# PHILOS PSYCHOL.csv                     0.0             6.0
# PSYCHOL REV.csv                       14.0            14.0
# PSYCHOL SCI.csv                        7.0            36.0
# PSYCHON B REV.csv                     12.0             8.0
# TRAV HUMAIN.csv                        0.0             0.0
#
#                           BEHAV BRAIN SCI.csv  BEHAV PROCESS.csv  \
# AM J PSYCHOL.csv                          0.0                0.0
# AM PSYCHOL.csv                           15.0                0.0
# BEHAV BRAIN SCI.csv                     126.0                8.0
# BEHAV PROCESS.csv                         5.0               70.0
# BRIT J PSYCHOL.csv                        4.0                0.0
# CHILD DEV.csv                            13.0                0.0
# COGNITION INSTRUCT.csv                    3.0                0.0
# COGNITION.csv                            28.0                0.0
# COGNITIVE PSYCHOL.csv                    10.0                0.0
# COGNITIVE SCI.csv                        33.0                7.0
# CONTEMP EDUC PSYCHOL.csv                  0.0                0.0
# DEV PSYCHOL.csv                          10.0                0.0
# DEV REV.csv                              12.0                0.0
# HUM FACTORS.csv                           0.0                0.0
# INT J HUM-COMPUT ST.csv                   0.0                0.0
# INT J SCI EDUC.csv                        0.0                0.0
# J CHILD LANG.csv                          3.0                0.0
# J COMP PSYCHOL.csv                       11.0               10.0
# J COMPUT ASSIST LEAR.csv                  0.0                0.0
# J EDUC PSYCHOL.csv                        3.0                0.0
# J EXP PSYCHOL ANIM B.csv                  4.0               21.0
# J EXP PSYCHOL GEN.csv                    20.0                0.0
# J EXP PSYCHOL LEARN.csv                  26.0                0.0
# J HUM EVOL.csv                            3.0                0.0
# J LEARN SCI.csv                           0.0                0.0
# J MEM LANG.csv                           22.0                0.0
# J PERS SOC PSYCHOL.csv                    9.0                0.0
# J PRAGMATICS.csv                          3.0                0.0
# J PSYCHOLINGUIST RES.csv                  5.0                0.0
# J RES SCI TEACH.csv                       2.0                0.0
# LEARN INSTR.csv                           0.0                0.0
# MEM COGNITION.csv                        17.0                0.0
# MONOGR SOC RES CHILD.csv                  0.0                0.0
# ORGAN BEHAV HUM DEC.csv                   2.0                0.0
# PHILOS PSYCHOL.csv                       22.0                0.0
# PSYCHOL REV.csv                          15.0                4.0
# PSYCHOL SCI.csv                          14.0                0.0
# PSYCHON B REV.csv                         8.0                0.0
# TRAV HUMAIN.csv                           2.0                0.0
#
#                           BRIT J PSYCHOL.csv  CHILD DEV.csv  \
# AM J PSYCHOL.csv                         9.0           12.0
# AM PSYCHOL.csv                           3.0           40.0
# BEHAV BRAIN SCI.csv                      3.0            8.0
# BEHAV PROCESS.csv                        3.0            0.0
# BRIT J PSYCHOL.csv                      30.0            4.0
# CHILD DEV.csv                            6.0          594.0
# COGNITION INSTRUCT.csv                   0.0           10.0
# COGNITION.csv                           11.0           49.0
# COGNITIVE PSYCHOL.csv                    7.0            5.0
# COGNITIVE SCI.csv                        8.0           23.0
# CONTEMP EDUC PSYCHOL.csv                 0.0           26.0
# DEV PSYCHOL.csv                          4.0          489.0
# DEV REV.csv                              2.0          139.0
# HUM FACTORS.csv                          0.0            0.0
# INT J HUM-COMPUT ST.csv                  3.0            0.0
# INT J SCI EDUC.csv                       0.0            2.0
# J CHILD LANG.csv                         2.0           29.0
# J COMP PSYCHOL.csv                       0.0           17.0
# J COMPUT ASSIST LEAR.csv                 0.0            0.0
# J EDUC PSYCHOL.csv                       5.0           96.0
# J EXP PSYCHOL ANIM B.csv                 0.0            0.0
# J EXP PSYCHOL GEN.csv                   14.0            5.0
# J EXP PSYCHOL LEARN.csv                 43.0           10.0
# J HUM EVOL.csv                           0.0            0.0
# J LEARN SCI.csv                          0.0            0.0
# J MEM LANG.csv                          13.0            4.0
# J PERS SOC PSYCHOL.csv                   7.0          104.0
# J PRAGMATICS.csv                         0.0            3.0
# J PSYCHOLINGUIST RES.csv                 0.0            2.0
# J RES SCI TEACH.csv                      0.0            4.0
# LEARN INSTR.csv                          0.0            7.0
# MEM COGNITION.csv                       33.0            5.0
# MONOGR SOC RES CHILD.csv                 0.0           33.0
# ORGAN BEHAV HUM DEC.csv                  0.0            3.0
# PHILOS PSYCHOL.csv                       0.0           10.0
# PSYCHOL REV.csv                         13.0           26.0
# PSYCHOL SCI.csv                          9.0           35.0
# PSYCHON B REV.csv                       15.0            7.0
# TRAV HUMAIN.csv                          0.0            0.0
#
#                           COGNITION INSTRUCT.csv  COGNITION.csv  \
# AM J PSYCHOL.csv                             0.0            4.0
# AM PSYCHOL.csv                               0.0            8.0
# BEHAV BRAIN SCI.csv                          0.0           52.0
# BEHAV PROCESS.csv                            0.0            0.0
# BRIT J PSYCHOL.csv                           0.0           12.0
# CHILD DEV.csv                                0.0           42.0
# COGNITION INSTRUCT.csv                      27.0            7.0
# COGNITION.csv                                8.0          177.0
# COGNITIVE PSYCHOL.csv                        0.0           42.0
# COGNITIVE SCI.csv                            5.0           20.0
# CONTEMP EDUC PSYCHOL.csv                     5.0            0.0
# DEV PSYCHOL.csv                              0.0           46.0
# DEV REV.csv                                  4.0           19.0
# HUM FACTORS.csv                              0.0            0.0
# INT J HUM-COMPUT ST.csv                      0.0            2.0
# INT J SCI EDUC.csv                          19.0            2.0
# J CHILD LANG.csv                             0.0           33.0
# J COMP PSYCHOL.csv                           0.0           11.0
# J COMPUT ASSIST LEAR.csv                    14.0            3.0
# J EDUC PSYCHOL.csv                          24.0           15.0
# J EXP PSYCHOL ANIM B.csv                     0.0            9.0
# J EXP PSYCHOL GEN.csv                        0.0           24.0
# J EXP PSYCHOL LEARN.csv                      0.0           87.0
# J HUM EVOL.csv                               0.0            0.0
# J LEARN SCI.csv                              8.0            0.0
# J MEM LANG.csv                               0.0           79.0
# J PERS SOC PSYCHOL.csv                       0.0            6.0
# J PRAGMATICS.csv                             0.0            5.0
# J PSYCHOLINGUIST RES.csv                     0.0           51.0
# J RES SCI TEACH.csv                         11.0            2.0
# LEARN INSTR.csv                              9.0            0.0
# MEM COGNITION.csv                            2.0           80.0
# MONOGR SOC RES CHILD.csv                     0.0            3.0
# ORGAN BEHAV HUM DEC.csv                      0.0            6.0
# PHILOS PSYCHOL.csv                           0.0           11.0
# PSYCHOL REV.csv                              0.0           55.0
# PSYCHOL SCI.csv                              0.0           37.0
# PSYCHON B REV.csv                            0.0           41.0
# TRAV HUMAIN.csv                              3.0            2.0
#
#                           COGNITIVE PSYCHOL.csv  COGNITIVE SCI.csv  \
# AM J PSYCHOL.csv                           27.0               12.0
# AM PSYCHOL.csv                              4.0                2.0
# BEHAV BRAIN SCI.csv                        41.0               30.0
# BEHAV PROCESS.csv                           0.0                0.0
# BRIT J PSYCHOL.csv                         12.0                5.0
# CHILD DEV.csv                              23.0                3.0
# COGNITION INSTRUCT.csv                     12.0               12.0
# COGNITION.csv                              64.0               24.0
# COGNITIVE PSYCHOL.csv                      45.0               22.0
# COGNITIVE SCI.csv                          19.0               35.0
# CONTEMP EDUC PSYCHOL.csv                   10.0               12.0
# DEV PSYCHOL.csv                            19.0                5.0
# DEV REV.csv                                17.0               10.0
# HUM FACTORS.csv                             5.0               11.0
# INT J HUM-COMPUT ST.csv                    13.0               29.0
# INT J SCI EDUC.csv                          8.0               12.0
# J CHILD LANG.csv                            5.0                5.0
# J COMP PSYCHOL.csv                          4.0                2.0
# J COMPUT ASSIST LEAR.csv                    2.0               17.0
# J EDUC PSYCHOL.csv                         12.0                8.0
# J EXP PSYCHOL ANIM B.csv                    5.0                0.0
# J EXP PSYCHOL GEN.csv                      46.0                5.0
# J EXP PSYCHOL LEARN.csv                   126.0               24.0
# J HUM EVOL.csv                              0.0                0.0
# J LEARN SCI.csv                             4.0               14.0
# J MEM LANG.csv                             59.0               14.0
# J PERS SOC PSYCHOL.csv                     21.0                2.0
# J PRAGMATICS.csv                            7.0                8.0
# J PSYCHOLINGUIST RES.csv                   20.0                8.0
# J RES SCI TEACH.csv                         0.0                7.0
# LEARN INSTR.csv                             3.0                8.0
# MEM COGNITION.csv                          97.0               36.0
# MONOGR SOC RES CHILD.csv                    9.0                0.0
# ORGAN BEHAV HUM DEC.csv                    18.0                7.0
# PHILOS PSYCHOL.csv                          4.0               10.0
# PSYCHOL REV.csv                            59.0               16.0
# PSYCHOL SCI.csv                            25.0                2.0
# PSYCHON B REV.csv                          47.0                8.0
# TRAV HUMAIN.csv                             0.0                7.0
#
#                                ...         J RES SCI TEACH.csv  \
# AM J PSYCHOL.csv               ...                         0.0
# AM PSYCHOL.csv                 ...                         0.0
# BEHAV BRAIN SCI.csv            ...                         0.0
# BEHAV PROCESS.csv              ...                         0.0
# BRIT J PSYCHOL.csv             ...                         0.0
# CHILD DEV.csv                  ...                         0.0
# COGNITION INSTRUCT.csv         ...                        22.0
# COGNITION.csv                  ...                         0.0
# COGNITIVE PSYCHOL.csv          ...                         0.0
# COGNITIVE SCI.csv              ...                         0.0
# CONTEMP EDUC PSYCHOL.csv       ...                         4.0
# DEV PSYCHOL.csv                ...                         0.0
# DEV REV.csv                    ...                         7.0
# HUM FACTORS.csv                ...                         2.0
# INT J HUM-COMPUT ST.csv        ...                         0.0
# INT J SCI EDUC.csv             ...                       171.0
# J CHILD LANG.csv               ...                         0.0
# J COMP PSYCHOL.csv             ...                         0.0
# J COMPUT ASSIST LEAR.csv       ...                         0.0
# J EDUC PSYCHOL.csv             ...                         5.0
# J EXP PSYCHOL ANIM B.csv       ...                         0.0
# J EXP PSYCHOL GEN.csv          ...                         0.0
# J EXP PSYCHOL LEARN.csv        ...                         0.0
# J HUM EVOL.csv                 ...                         0.0
# J LEARN SCI.csv                ...                        12.0
# J MEM LANG.csv                 ...                         0.0
# J PERS SOC PSYCHOL.csv         ...                         0.0
# J PRAGMATICS.csv               ...                         0.0
# J PSYCHOLINGUIST RES.csv       ...                         0.0
# J RES SCI TEACH.csv            ...                       316.0
# LEARN INSTR.csv                ...                         8.0
# MEM COGNITION.csv              ...                         0.0
# MONOGR SOC RES CHILD.csv       ...                         0.0
# ORGAN BEHAV HUM DEC.csv        ...                         0.0
# PHILOS PSYCHOL.csv             ...                         0.0
# PSYCHOL REV.csv                ...                         0.0
# PSYCHOL SCI.csv                ...                         0.0
# PSYCHON B REV.csv              ...                         0.0
# TRAV HUMAIN.csv                ...                         0.0
#
#                           LEARN INSTR.csv  MEM COGNITION.csv  \
# AM J PSYCHOL.csv                      2.0               49.0
# AM PSYCHOL.csv                        0.0                0.0
# BEHAV BRAIN SCI.csv                   0.0               13.0
# BEHAV PROCESS.csv                     0.0                4.0
# BRIT J PSYCHOL.csv                    0.0               22.0
# CHILD DEV.csv                         0.0                8.0
# COGNITION INSTRUCT.csv                3.0                3.0
# COGNITION.csv                         0.0               37.0
# COGNITIVE PSYCHOL.csv                 0.0               25.0
# COGNITIVE SCI.csv                     0.0               10.0
# CONTEMP EDUC PSYCHOL.csv              0.0               16.0
# DEV PSYCHOL.csv                       0.0               16.0
# DEV REV.csv                           0.0                7.0
# HUM FACTORS.csv                       0.0                4.0
# INT J HUM-COMPUT ST.csv               0.0                3.0
# INT J SCI EDUC.csv                   11.0                0.0
# J CHILD LANG.csv                      0.0                2.0
# J COMP PSYCHOL.csv                    0.0                0.0
# J COMPUT ASSIST LEAR.csv              6.0                3.0
# J EDUC PSYCHOL.csv                    6.0               15.0
# J EXP PSYCHOL ANIM B.csv              0.0                2.0
# J EXP PSYCHOL GEN.csv                 0.0               44.0
# J EXP PSYCHOL LEARN.csv               0.0              301.0
# J HUM EVOL.csv                        0.0                0.0
# J LEARN SCI.csv                       4.0                0.0
# J MEM LANG.csv                        0.0              112.0
# J PERS SOC PSYCHOL.csv                0.0                6.0
# J PRAGMATICS.csv                      0.0                2.0
# J PSYCHOLINGUIST RES.csv              0.0                8.0
# J RES SCI TEACH.csv                   5.0                0.0
# LEARN INSTR.csv                      42.0                2.0
# MEM COGNITION.csv                     0.0              323.0
# MONOGR SOC RES CHILD.csv              0.0                3.0
# ORGAN BEHAV HUM DEC.csv               0.0               15.0
# PHILOS PSYCHOL.csv                    0.0                2.0
# PSYCHOL REV.csv                       0.0               76.0
# PSYCHOL SCI.csv                       0.0               29.0
# PSYCHON B REV.csv                     0.0              162.0
# TRAV HUMAIN.csv                       0.0                2.0
#
#                           MONOGR SOC RES CHILD.csv  ORGAN BEHAV HUM DEC.csv  \
# AM J PSYCHOL.csv                               0.0                      6.0
# AM PSYCHOL.csv                                10.0                      4.0
# BEHAV BRAIN SCI.csv                            0.0                      3.0
# BEHAV PROCESS.csv                              0.0                      0.0
# BRIT J PSYCHOL.csv                             0.0                      2.0
# CHILD DEV.csv                                 67.0                      0.0
# COGNITION INSTRUCT.csv                         7.0                      0.0
# COGNITION.csv                                 11.0                      0.0
# COGNITIVE PSYCHOL.csv                          0.0                      0.0
# COGNITIVE SCI.csv                             10.0                     14.0
# CONTEMP EDUC PSYCHOL.csv                       0.0                      0.0
# DEV PSYCHOL.csv                               30.0                      0.0
# DEV REV.csv                                   24.0                      0.0
# HUM FACTORS.csv                                0.0                      6.0
# INT J HUM-COMPUT ST.csv                        0.0                      8.0
# INT J SCI EDUC.csv                             0.0                      0.0
# J CHILD LANG.csv                              21.0                      0.0
# J COMP PSYCHOL.csv                             3.0                      0.0
# J COMPUT ASSIST LEAR.csv                       0.0                      0.0
# J EDUC PSYCHOL.csv                             4.0                      6.0
# J EXP PSYCHOL ANIM B.csv                       0.0                      0.0
# J EXP PSYCHOL GEN.csv                          0.0                      4.0
# J EXP PSYCHOL LEARN.csv                        0.0                     21.0
# J HUM EVOL.csv                                 0.0                      0.0
# J LEARN SCI.csv                                0.0                      0.0
# J MEM LANG.csv                                 0.0                      0.0
# J PERS SOC PSYCHOL.csv                        11.0                     53.0
# J PRAGMATICS.csv                               0.0                      0.0
# J PSYCHOLINGUIST RES.csv                       0.0                      0.0
# J RES SCI TEACH.csv                            0.0                      0.0
# LEARN INSTR.csv                                0.0                      0.0
# MEM COGNITION.csv                              0.0                      6.0
# MONOGR SOC RES CHILD.csv                      10.0                      0.0
# ORGAN BEHAV HUM DEC.csv                        0.0                    198.0
# PHILOS PSYCHOL.csv                             0.0                      0.0
# PSYCHOL REV.csv                                2.0                     49.0
# PSYCHOL SCI.csv                                5.0                      4.0
# PSYCHON B REV.csv                              0.0                      0.0
# TRAV HUMAIN.csv                                0.0                      0.0
#
#                           PHILOS PSYCHOL.csv  PSYCHOL REV.csv  \
# AM J PSYCHOL.csv                         0.0             47.0
# AM PSYCHOL.csv                           5.0             75.0
# BEHAV BRAIN SCI.csv                      0.0            194.0
# BEHAV PROCESS.csv                        0.0             32.0
# BRIT J PSYCHOL.csv                       0.0             35.0
# CHILD DEV.csv                            0.0             49.0
# COGNITION INSTRUCT.csv                   0.0             10.0
# COGNITION.csv                            0.0             97.0
# COGNITIVE PSYCHOL.csv                    0.0             71.0
# COGNITIVE SCI.csv                        0.0             34.0
# CONTEMP EDUC PSYCHOL.csv                 0.0             19.0
# DEV PSYCHOL.csv                          0.0             46.0
# DEV REV.csv                              0.0             26.0
# HUM FACTORS.csv                          0.0              7.0
# INT J HUM-COMPUT ST.csv                  0.0             19.0
# INT J SCI EDUC.csv                       0.0              4.0
# J CHILD LANG.csv                         0.0              8.0
# J COMP PSYCHOL.csv                       0.0              9.0
# J COMPUT ASSIST LEAR.csv                 0.0              5.0
# J EDUC PSYCHOL.csv                       0.0             27.0
# J EXP PSYCHOL ANIM B.csv                 0.0             60.0
# J EXP PSYCHOL GEN.csv                    0.0             95.0
# J EXP PSYCHOL LEARN.csv                  0.0            360.0
# J HUM EVOL.csv                           0.0              0.0
# J LEARN SCI.csv                          0.0              0.0
# J MEM LANG.csv                           0.0            153.0
# J PERS SOC PSYCHOL.csv                   0.0            236.0
# J PRAGMATICS.csv                         0.0              8.0
# J PSYCHOLINGUIST RES.csv                 0.0             30.0
# J RES SCI TEACH.csv                      0.0              8.0
# LEARN INSTR.csv                          0.0              7.0
# MEM COGNITION.csv                        0.0            214.0
# MONOGR SOC RES CHILD.csv                 0.0             10.0
# ORGAN BEHAV HUM DEC.csv                  0.0             63.0
# PHILOS PSYCHOL.csv                      10.0             13.0
# PSYCHOL REV.csv                          0.0            306.0
# PSYCHOL SCI.csv                          0.0             76.0
# PSYCHON B REV.csv                        0.0            197.0
# TRAV HUMAIN.csv                          0.0              0.0
#
#                           PSYCHOL SCI.csv  PSYCHON B REV.csv  TRAV HUMAIN.csv
# AM J PSYCHOL.csv                     13.0                9.0              0.0
# AM PSYCHOL.csv                       21.0                0.0              0.0
# BEHAV BRAIN SCI.csv                  19.0               15.0              0.0
# BEHAV PROCESS.csv                     3.0               13.0              0.0
# BRIT J PSYCHOL.csv                   10.0                6.0              0.0
# CHILD DEV.csv                        21.0                5.0              0.0
# COGNITION INSTRUCT.csv                2.0                0.0              0.0
# COGNITION.csv                        25.0               14.0              0.0
# COGNITIVE PSYCHOL.csv                 9.0                6.0              0.0
# COGNITIVE SCI.csv                     9.0                2.0              0.0
# CONTEMP EDUC PSYCHOL.csv              0.0                2.0              0.0
# DEV PSYCHOL.csv                      11.0                4.0              0.0
# DEV REV.csv                           5.0                0.0              0.0
# HUM FACTORS.csv                       2.0                0.0              3.0
# INT J HUM-COMPUT ST.csv               0.0                0.0              3.0
# INT J SCI EDUC.csv                    0.0                0.0              0.0
# J CHILD LANG.csv                      2.0                0.0              0.0
# J COMP PSYCHOL.csv                    7.0                2.0              0.0
# J COMPUT ASSIST LEAR.csv              0.0                0.0              0.0
# J EDUC PSYCHOL.csv                    5.0                2.0              0.0
# J EXP PSYCHOL ANIM B.csv             11.0                3.0              0.0
# J EXP PSYCHOL GEN.csv                21.0               32.0              0.0
# J EXP PSYCHOL LEARN.csv              45.0               71.0              0.0
# J HUM EVOL.csv                        0.0                0.0              0.0
# J LEARN SCI.csv                       0.0                0.0              0.0
# J MEM LANG.csv                       22.0               35.0              0.0
# J PERS SOC PSYCHOL.csv               49.0                4.0              0.0
# J PRAGMATICS.csv                      3.0                0.0              0.0
# J PSYCHOLINGUIST RES.csv              4.0                0.0              0.0
# J RES SCI TEACH.csv                   0.0                0.0              0.0
# LEARN INSTR.csv                       0.0                0.0              0.0
# MEM COGNITION.csv                    52.0               63.0              0.0
# MONOGR SOC RES CHILD.csv              0.0                0.0              0.0
# ORGAN BEHAV HUM DEC.csv               9.0                2.0              0.0
# PHILOS PSYCHOL.csv                    4.0                0.0              0.0
# PSYCHOL REV.csv                      20.0               20.0              0.0
# PSYCHOL SCI.csv                      71.0               18.0              0.0
# PSYCHON B REV.csv                    36.0               70.0              0.0
# TRAV HUMAIN.csv                       0.0                0.0             15.0
#
# [39 rows x 39 columns]

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.log(JMatrix))
#np.where(np.sum(JMatrix.as_matrix(), axis=0)==0)#getting nothing in the array[] means dylan didnt screw up (:
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Decomposition

# %%
# SVD and PCA gives essentially the same answer, as it should, with rotational indeterminancy
#citation_svd = decomposition.TruncatedSVD(n_components=20)
citation_svd = decomposition.PCA(n_components=20, whiten=False)

# apply matrix factorization to citation matrix
citation_svd.fit(JMatrix.as_matrix())
JMatrix_reduced = citation_svd.transform(JMatrix.as_matrix())

# how many components required to capture 95% variance?
np.where(np.cumsum(citation_svd.explained_variance_ratio_)>=0.95)[0][0]

# cog sci is element 9
ctr_j=9
print(Jabbr[ctr_j])
plt.figure(figsize=(15,4))
plt.subplot(1,4,1)
plt.plot(np.cumsum(citation_svd.explained_variance_ratio_))
plt.subplot(1,4,2)
plt.imshow(JMatrix_reduced)
plt.subplot(1,4,3)
# # Cogsci's reduced vector
# plt.plot(JMatrix_reduced[ctr_j,:],'.')
# # Cogsci's components
# plt.subplot(1,4,4)
# plt.plot(citation_svd.components_[:,ctr_j]);
# plt.tight_layout()
# Out:
# COGNITIVE SCI

# %%
# k-means clustering
n_clusters = 5
clu = cluster.KMeans(n_clusters=n_clusters)

clu.fit(JMatrix_reduced)
clu_label = clu.labels_
clu_inds = np.argsort(clu_label)
clu_label
clustered_J = [[Jabbr[i] for i in np.where(clu_label==query_clu)[0]] for query_clu in range(n_clusters)]
pd.DataFrame([t[:20] for t in clustered_J], index=['Clu%i'%i for i in range(n_clusters)]).T
# Out:
#                     Clu0                Clu1           Clu2         Clu3  \
# 0           AM J PSYCHOL  J PERS SOC PSYCHOL     J MEM LANG    CHILD DEV
# 1             AM PSYCHOL                None    PSYCHOL REV  DEV PSYCHOL
# 2        BEHAV BRAIN SCI                None  PSYCHON B REV         None
# 3          BEHAV PROCESS                None           None         None
# 4         BRIT J PSYCHOL                None           None         None
# 5     COGNITION INSTRUCT                None           None         None
# 6              COGNITION                None           None         None
# 7      COGNITIVE PSYCHOL                None           None         None
# 8          COGNITIVE SCI                None           None         None
# 9   CONTEMP EDUC PSYCHOL                None           None         None
# 10               DEV REV                None           None         None
# 11           HUM FACTORS                None           None         None
# 12   INT J HUM-COMPUT ST                None           None         None
# 13        INT J SCI EDUC                None           None         None
# 14          J CHILD LANG                None           None         None
# 15        J COMP PSYCHOL                None           None         None
# 16  J COMPUT ASSIST LEAR                None           None         None
# 17        J EDUC PSYCHOL                None           None         None
# 18  J EXP PSYCHOL ANIM B                None           None         None
# 19     J EXP PSYCHOL GEN                None           None         None
#
#                    Clu4
# 0   J EXP PSYCHOL LEARN
# 1         MEM COGNITION
# 2                  None
# 3                  None
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
# 10                 None
# 11                 None
# 12                 None
# 13                 None
# 14                 None
# 15                 None
# 16                 None
# 17                 None
# 18                 None
# 19                 None
